# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import nltk
from nltk.corpus import wordnet
nltk.download('wordnet')
nltk.download('omw-1.4')
from sklearn.model_selection import train_test_split, KFold
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import (
    Embedding, Bidirectional, LSTM, Dense, Dropout,
    BatchNormalization, SpatialDropout1D, Conv1D,
    MaxPooling1D, GlobalMaxPooling1D, concatenate,
    Input, Add
)
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
import re
import warnings
import os
from sklearn.metrics import confusion_matrix, classification_report
import itertools

np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

GLOVE_EMBEDDINGS_PATH = 'glove.6B.100d.txt'
MODEL_SAVE_PATH = 'model/best_intent_model.h5'

def load_and_preprocess_data(file_path):
    data = pd.read_excel(file_path)
    print("Dataset shape:", data.shape)
    print("\nClass distribution:")
    print(data['Category'].value_counts())
    return data

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)
    return text.strip()

def prepare_text_data(data):
    data['Query'] = data['Query'].apply(clean_text)

    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(data['Query'])

    sequences = tokenizer.texts_to_sequences(data['Query'])
    max_sequence_length = max(len(seq) for seq in sequences)
    X = pad_sequences(sequences, maxlen=max_sequence_length, padding='post')

    intent_labels = list(set(data['Category']))
    intent_to_index = {intent: i for i, intent in enumerate(intent_labels)}
    y = np.array([intent_to_index[intent] for intent in data['Category']])

    return X, y, tokenizer, max_sequence_length, intent_labels, intent_to_index

def synonym_replace(text):
    words = text.split()
    if len(words) < 3:
        return text
    idx = np.random.randint(0, len(words))
    synonyms = [syn.lemmas()[0].name() for syn in wordnet.synsets(words[idx]) if syn.lemmas()]
    if synonyms:
        words[idx] = np.random.choice(synonyms)
    return ' '.join(words)

def augment_text(text, max_augmented=3):
    augmented = [text]
    augmented.append(synonym_replace(text))
    words = text.split()
    if len(words) > 3:
        shuffled = words.copy()
        np.random.shuffle(shuffled)
        augmented.append(' '.join(shuffled))
    return augmented[:max_augmented]

def augment_dataset(X, y, tokenizer, max_sequence_length):
    augmented_texts = []
    augmented_labels = []

    original_texts = []
    for seq in X:
        text = []
        for idx in seq:
            if idx != 0:
                for word, word_idx in tokenizer.word_index.items():
                    if word_idx == idx:
                        text.append(word)
                        break
        original_texts.append(' '.join(text))

    for text, label in zip(original_texts, y):
        aug_texts = augment_text(text)
        augmented_texts.extend(aug_texts)
        augmented_labels.extend([label] * len(aug_texts))

    aug_sequences = tokenizer.texts_to_sequences(augmented_texts)
    X_aug = pad_sequences(aug_sequences, maxlen=max_sequence_length, padding='post')
    y_aug = np.array(augmented_labels)

    return X_aug, y_aug

def load_glove_embeddings(word_index, embedding_dim=94):
    if not os.path.exists(GLOVE_EMBEDDINGS_PATH):
        print(f"Warning: GloVe embeddings file {GLOVE_EMBEDDINGS_PATH} not found.")
        return None

    embeddings_index = {}
    try:
        with open(GLOVE_EMBEDDINGS_PATH, encoding='utf-8') as f:
            first_line = next(f)
            actual_dim = len(first_line.split()) - 1
            if actual_dim != embedding_dim:
                print(f"Warning: Expected embedding dimension {embedding_dim} but found {actual_dim}")
                embedding_dim = actual_dim

            f.seek(0)

            for line in f:
                values = line.split()
                word = values[0]
                coefs = np.asarray(values[1:], dtype='float32')
                embeddings_index[word] = coefs

        embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
        for word, i in word_index.items():
            embedding_vector = embeddings_index.get(word)
            if embedding_vector is not None:
                embedding_matrix[i] = embedding_vector

        return embedding_matrix
    except Exception as e:
        print(f"Error loading GloVe embeddings: {e}")
        return None

def create_enhanced_model(vocab_size, embedding_dim, max_sequence_length, num_classes, embedding_matrix=None):
    input_layer = Input(shape=(max_sequence_length,))
    embedding = Embedding(
        input_dim=vocab_size, output_dim=embedding_dim, input_length=max_sequence_length,
        weights=[embedding_matrix] if embedding_matrix is not None else None,
        trainable=False if embedding_matrix is not None else True
    )(input_layer)
    embedding_dropout = SpatialDropout1D(0.2)(embedding)

    conv1 = Conv1D(64, 3, activation='relu', padding='same')(embedding_dropout)
    pool1 = MaxPooling1D(2)(conv1)
    global_pool = GlobalMaxPooling1D()(conv1)

    lstm1 = Bidirectional(LSTM(64, return_sequences=False, kernel_regularizer=l2(1e-4)))(embedding_dropout)
    bn1 = BatchNormalization()(lstm1)

    merged = concatenate([global_pool, bn1])
    dense = Dense(64, activation='relu', kernel_regularizer=l2(1e-4))(merged)
    dropout = Dropout(0.3)(dense)
    output_layer = Dense(num_classes, activation='softmax')(dropout)

    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(optimizer=Adam(learning_rate=0.0001, clipnorm=1.0),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

def get_enhanced_training_config():
    return {
        'batch_size': 64,
        'epochs': 50,
        'callbacks': [
            EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, min_delta=0.001),
            ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-7, verbose=1),
            ModelCheckpoint(MODEL_SAVE_PATH, monitor='val_loss', save_best_only=True, verbose=1)
        ]
    }

def plot_confusion_matrix(y_true, y_pred, classes, normalize=False, title='Confusion Matrix'):
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='.2f' if normalize else 'd',
                cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.title(title)
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.show()

def plot_training_metrics(history, fold=None):
    metrics = ['loss', 'accuracy' if 'accuracy' in history.history else 'acc']

    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    fig.suptitle(f'Training Metrics {f"(Fold {fold})" if fold else ""}')

    for idx, metric in enumerate(metrics):
        axes[idx].plot(history.history[metric], label='Train')
        axes[idx].plot(history.history.get(f'val_{metric}', []), label='Validation')
        axes[idx].set_title(f'Model {metric.capitalize()}')
        axes[idx].set_xlabel('Epoch')
        axes[idx].set_ylabel(metric.capitalize())
        axes[idx].legend()

    plt.tight_layout()
    plt.show()

def train_enhanced_model(X, y, vocab_size, embedding_dim, max_sequence_length,
                         num_classes, embedding_matrix=None, n_splits=5):
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    fold_scores = []
    training_config = get_enhanced_training_config()
    all_predictions = []
    all_true_labels = []

    for fold, (train_idx, val_idx) in enumerate(kfold.split(X)):
        print(f'\nTraining fold {fold + 1}/{n_splits}')

        # Split data
        X_fold_train, y_fold_train = X[train_idx], y[train_idx]
        X_fold_val, y_fold_val = X[val_idx], y[val_idx]

        class_weights = compute_class_weight(
            class_weight="balanced",
            classes=np.unique(y_fold_train),
            y=y_fold_train
        )
        class_weight_dict = dict(enumerate(class_weights))

        model = create_enhanced_model(
            vocab_size, embedding_dim, max_sequence_length,
            num_classes, embedding_matrix
        )

        history = model.fit(
            X_fold_train, y_fold_train,
            validation_data=(X_fold_val, y_fold_val),
            class_weight=class_weight_dict,
            **training_config
        )

        val_loss, val_acc = model.evaluate(X_fold_val, y_fold_val)
        fold_scores.append(val_acc)

        y_pred = np.argmax(model.predict(X_fold_val), axis=1)
        all_predictions.extend(y_pred)
        all_true_labels.extend(y_fold_val)

        plot_training_metrics(history, fold + 1)

    plot_confusion_matrix(
        all_true_labels, all_predictions,
        classes=range(num_classes),
        normalize=True,
        title='Overall Normalized Confusion Matrix'
    )

    print(f'\nClassification Report:')
    print(classification_report(all_true_labels, all_predictions))
    print(f'\nAverage validation accuracy: {np.mean(fold_scores):.4f} ± {np.std(fold_scores):.4f}')

    return fold_scores

def predict_intent(text, model, tokenizer, max_sequence_length, intent_labels):
    cleaned_text = clean_text(text)
    sequence = tokenizer.texts_to_sequences([cleaned_text])
    padded_sequence = pad_sequences(sequence, maxlen=max_sequence_length, padding='post')

    prediction = model.predict(padded_sequence)
    predicted_class = np.argmax(prediction[0])
    confidence = prediction[0][predicted_class]

    return intent_labels[predicted_class], confidence

def main():
    data = load_and_preprocess_data("cleaned_data.xlsx")
    X, y, tokenizer, max_sequence_length, intent_labels, intent_to_index = prepare_text_data(data)

    embedding_dim = 100
    vocab_size = len(tokenizer.word_index) + 1
    num_classes = len(intent_labels)
    embedding_matrix = load_glove_embeddings(tokenizer.word_index, embedding_dim)

    X_aug, y_aug = augment_dataset(X, y, tokenizer, max_sequence_length)

    fold_scores = train_enhanced_model(
        X_aug, y_aug,
        vocab_size, embedding_dim, max_sequence_length,
        num_classes, embedding_matrix
    )

    if os.path.exists(MODEL_SAVE_PATH):
        best_model = load_model(MODEL_SAVE_PATH)
        test_query = "How do I properly dispose of electronic waste?"
        intent, confidence = predict_intent(
            test_query, best_model, tokenizer,
            max_sequence_length, intent_labels
        )
        print(f"\nTest Query: {test_query}")
        print(f"Predicted Intent: {intent}")
        print(f"Confidence: {confidence:.2f}")
    else:
        print("No saved model found. Please train the model first.")

    return tokenizer, intent_labels, intent_to_index

if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Dataset shape: (1379, 2)
#
# Class distribution:
# Category
# Public Awareness Tips         200
# Complaints                    200
# Feedback                      200
# Unknown                       200
# Waste Collection Schedules    199
# 3R Tips                       198
# Greetings                     182
# Name: count, dtype: int64
#
# Training fold 1/5
# Epoch 1/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.1766 - loss: 2.3746
# Epoch 1: val_loss improved from inf to 1.86796, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 12s 76ms/step - accuracy: 0.1777 - loss: 2.3674 - val_accuracy: 0.3386 - val_loss: 1.8680 - learning_rate: 1.0000e-04
# Epoch 2/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3558 - loss: 1.7157
# Epoch 2: val_loss improved from 1.86796 to 1.71215, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.3578 - loss: 1.7113 - val_accuracy: 0.4800 - val_loss: 1.7122 - learning_rate: 1.0000e-04
# Epoch 3/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5157 - loss: 1.3560
# Epoch 3: val_loss improved from 1.71215 to 1.51932, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5169 - loss: 1.3527 - val_accuracy: 0.6421 - val_loss: 1.5193 - learning_rate: 1.0000e-04
# Epoch 4/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6279 - loss: 1.0793
# Epoch 4: val_loss improved from 1.51932 to 1.29039, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.6287 - loss: 1.0774 - val_accuracy: 0.7715 - val_loss: 1.2904 - learning_rate: 1.0000e-04
# Epoch 5/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7099 - loss: 0.8928
# Epoch 5: val_loss improved from 1.29039 to 1.04897, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.7102 - loss: 0.8920 - val_accuracy: 0.8501 - val_loss: 1.0490 - learning_rate: 1.0000e-04
# Epoch 6/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7469 - loss: 0.7745
# Epoch 6: val_loss improved from 1.04897 to 0.82539, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.7476 - loss: 0.7731 - val_accuracy: 0.8875 - val_loss: 0.8254 - learning_rate: 1.0000e-04
# Epoch 7/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7938 - loss: 0.6695
# Epoch 7: val_loss improved from 0.82539 to 0.63181, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7941 - loss: 0.6686 - val_accuracy: 0.9093 - val_loss: 0.6318 - learning_rate: 1.0000e-04
# Epoch 8/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8055 - loss: 0.5987
# Epoch 8: val_loss improved from 0.63181 to 0.47975, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8062 - loss: 0.5979 - val_accuracy: 0.9347 - val_loss: 0.4797 - learning_rate: 1.0000e-04
# Epoch 9/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8277 - loss: 0.5350
# Epoch 9: val_loss improved from 0.47975 to 0.37152, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8283 - loss: 0.5342 - val_accuracy: 0.9504 - val_loss: 0.3715 - learning_rate: 1.0000e-04
# Epoch 10/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8563 - loss: 0.4846
# Epoch 10: val_loss improved from 0.37152 to 0.29844, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.8568 - loss: 0.4837 - val_accuracy: 0.9565 - val_loss: 0.2984 - learning_rate: 1.0000e-04
# Epoch 11/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8678 - loss: 0.4362
# Epoch 11: val_loss improved from 0.29844 to 0.25026, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8682 - loss: 0.4355 - val_accuracy: 0.9613 - val_loss: 0.2503 - learning_rate: 1.0000e-04
# Epoch 12/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8848 - loss: 0.3922
# Epoch 12: val_loss improved from 0.25026 to 0.21433, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8850 - loss: 0.3916 - val_accuracy: 0.9637 - val_loss: 0.2143 - learning_rate: 1.0000e-04
# Epoch 13/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8946 - loss: 0.3746
# Epoch 13: val_loss improved from 0.21433 to 0.19376, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.8946 - loss: 0.3744 - val_accuracy: 0.9649 - val_loss: 0.1938 - learning_rate: 1.0000e-04
# Epoch 14/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8962 - loss: 0.3600
# Epoch 14: val_loss improved from 0.19376 to 0.17660, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8966 - loss: 0.3592 - val_accuracy: 0.9686 - val_loss: 0.1766 - learning_rate: 1.0000e-04
# Epoch 15/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9152 - loss: 0.3174
# Epoch 15: val_loss improved from 0.17660 to 0.15966, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.9150 - loss: 0.3173 - val_accuracy: 0.9734 - val_loss: 0.1597 - learning_rate: 1.0000e-04
# Epoch 16/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9036 - loss: 0.3288
# Epoch 16: val_loss improved from 0.15966 to 0.15273, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.9040 - loss: 0.3279 - val_accuracy: 0.9734 - val_loss: 0.1527 - learning_rate: 1.0000e-04
# Epoch 17/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9255 - loss: 0.2852
# Epoch 17: val_loss improved from 0.15273 to 0.14524, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9255 - loss: 0.2848 - val_accuracy: 0.9746 - val_loss: 0.1452 - learning_rate: 1.0000e-04
# Epoch 18/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9325 - loss: 0.2711
# Epoch 18: val_loss improved from 0.14524 to 0.13668, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.9324 - loss: 0.2710 - val_accuracy: 0.9746 - val_loss: 0.1367 - learning_rate: 1.0000e-04
# Epoch 19/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9235 - loss: 0.2715
# Epoch 19: val_loss improved from 0.13668 to 0.12951, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9238 - loss: 0.2710 - val_accuracy: 0.9770 - val_loss: 0.1295 - learning_rate: 1.0000e-04
# Epoch 20/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9251 - loss: 0.2586
# Epoch 20: val_loss improved from 0.12951 to 0.12346, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9252 - loss: 0.2585 - val_accuracy: 0.9770 - val_loss: 0.1235 - learning_rate: 1.0000e-04
# Epoch 21/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9407 - loss: 0.2426
# Epoch 21: val_loss improved from 0.12346 to 0.11992, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9407 - loss: 0.2424 - val_accuracy: 0.9782 - val_loss: 0.1199 - learning_rate: 1.0000e-04
# Epoch 22/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9327 - loss: 0.2528
# Epoch 22: val_loss improved from 0.11992 to 0.11508, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.9327 - loss: 0.2523 - val_accuracy: 0.9782 - val_loss: 0.1151 - learning_rate: 1.0000e-04
# Epoch 23/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9343 - loss: 0.2379
# Epoch 23: val_loss improved from 0.11508 to 0.11035, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.9346 - loss: 0.2374 - val_accuracy: 0.9794 - val_loss: 0.1104 - learning_rate: 1.0000e-04
# Epoch 24/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9462 - loss: 0.2193
# Epoch 24: val_loss improved from 0.11035 to 0.10472, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9462 - loss: 0.2191 - val_accuracy: 0.9843 - val_loss: 0.1047 - learning_rate: 1.0000e-04
# Epoch 25/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9446 - loss: 0.2197
# Epoch 25: val_loss improved from 0.10472 to 0.10256, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9449 - loss: 0.2191 - val_accuracy: 0.9819 - val_loss: 0.1026 - learning_rate: 1.0000e-04
# Epoch 26/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9398 - loss: 0.2140
# Epoch 26: val_loss improved from 0.10256 to 0.09942, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9402 - loss: 0.2134 - val_accuracy: 0.9831 - val_loss: 0.0994 - learning_rate: 1.0000e-04
# Epoch 27/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9489 - loss: 0.2023
# Epoch 27: val_loss improved from 0.09942 to 0.09810, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9491 - loss: 0.2019 - val_accuracy: 0.9867 - val_loss: 0.0981 - learning_rate: 1.0000e-04
# Epoch 28/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9545 - loss: 0.1904
# Epoch 28: val_loss improved from 0.09810 to 0.09531, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9545 - loss: 0.1903 - val_accuracy: 0.9867 - val_loss: 0.0953 - learning_rate: 1.0000e-04
# Epoch 29/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9596 - loss: 0.1710
# Epoch 29: val_loss improved from 0.09531 to 0.08940, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9596 - loss: 0.1711 - val_accuracy: 0.9879 - val_loss: 0.0894 - learning_rate: 1.0000e-04
# Epoch 30/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9522 - loss: 0.1885
# Epoch 30: val_loss improved from 0.08940 to 0.08620, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9524 - loss: 0.1879 - val_accuracy: 0.9879 - val_loss: 0.0862 - learning_rate: 1.0000e-04
# Epoch 31/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9583 - loss: 0.1702
# Epoch 31: val_loss did not improve from 0.08620
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9583 - loss: 0.1700 - val_accuracy: 0.9867 - val_loss: 0.0873 - learning_rate: 1.0000e-04
# Epoch 32/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9537 - loss: 0.1775
# Epoch 32: val_loss improved from 0.08620 to 0.08286, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9539 - loss: 0.1770 - val_accuracy: 0.9855 - val_loss: 0.0829 - learning_rate: 1.0000e-04
# Epoch 33/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9602 - loss: 0.1687
# Epoch 33: val_loss did not improve from 0.08286
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.9603 - loss: 0.1685 - val_accuracy: 0.9855 - val_loss: 0.0863 - learning_rate: 1.0000e-04
# Epoch 34/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9582 - loss: 0.1614
# Epoch 34: val_loss did not improve from 0.08286
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9583 - loss: 0.1612 - val_accuracy: 0.9855 - val_loss: 0.0848 - learning_rate: 1.0000e-04
# Epoch 35/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9664 - loss: 0.1545
# Epoch 35: val_loss improved from 0.08286 to 0.08055, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9663 - loss: 0.1544 - val_accuracy: 0.9903 - val_loss: 0.0806 - learning_rate: 1.0000e-04
# Epoch 36/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9584 - loss: 0.1547
# Epoch 36: val_loss improved from 0.08055 to 0.07794, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9588 - loss: 0.1541 - val_accuracy: 0.9891 - val_loss: 0.0779 - learning_rate: 1.0000e-04
# Epoch 37/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9687 - loss: 0.1382
# Epoch 37: val_loss improved from 0.07794 to 0.07687, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9687 - loss: 0.1381 - val_accuracy: 0.9903 - val_loss: 0.0769 - learning_rate: 1.0000e-04
# Epoch 38/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9633 - loss: 0.1526
# Epoch 38: val_loss did not improve from 0.07687
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9634 - loss: 0.1521 - val_accuracy: 0.9915 - val_loss: 0.0773 - learning_rate: 1.0000e-04
# Epoch 39/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9588 - loss: 0.1547
# Epoch 39: val_loss improved from 0.07687 to 0.07675, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9592 - loss: 0.1540 - val_accuracy: 0.9903 - val_loss: 0.0768 - learning_rate: 1.0000e-04
# Epoch 40/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9599 - loss: 0.1531
# Epoch 40: val_loss improved from 0.07675 to 0.07637, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9602 - loss: 0.1525 - val_accuracy: 0.9903 - val_loss: 0.0764 - learning_rate: 1.0000e-04
# Epoch 41/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9689 - loss: 0.1356
# Epoch 41: val_loss improved from 0.07637 to 0.07534, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9690 - loss: 0.1355 - val_accuracy: 0.9915 - val_loss: 0.0753 - learning_rate: 1.0000e-04
# Epoch 42/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9743 - loss: 0.1263
# Epoch 42: val_loss improved from 0.07534 to 0.07335, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9743 - loss: 0.1262 - val_accuracy: 0.9915 - val_loss: 0.0734 - learning_rate: 1.0000e-04
# Epoch 43/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9763 - loss: 0.1226
# Epoch 43: val_loss did not improve from 0.07335
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9763 - loss: 0.1225 - val_accuracy: 0.9879 - val_loss: 0.0753 - learning_rate: 1.0000e-04
# Epoch 44/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9700 - loss: 0.1311
# Epoch 44: val_loss improved from 0.07335 to 0.07162, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9700 - loss: 0.1309 - val_accuracy: 0.9903 - val_loss: 0.0716 - learning_rate: 1.0000e-04
# Epoch 45/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9731 - loss: 0.1285
# Epoch 45: val_loss improved from 0.07162 to 0.07029, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9732 - loss: 0.1283 - val_accuracy: 0.9915 - val_loss: 0.0703 - learning_rate: 1.0000e-04
# Epoch 46/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9751 - loss: 0.1198
# Epoch 46: val_loss improved from 0.07029 to 0.06725, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.9751 - loss: 0.1196 - val_accuracy: 0.9903 - val_loss: 0.0672 - learning_rate: 1.0000e-04
# Epoch 47/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9750 - loss: 0.1118
# Epoch 47: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9749 - loss: 0.1120 - val_accuracy: 0.9915 - val_loss: 0.0694 - learning_rate: 1.0000e-04
# Epoch 48/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9730 - loss: 0.1296
# Epoch 48: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9730 - loss: 0.1292 - val_accuracy: 0.9915 - val_loss: 0.0695 - learning_rate: 1.0000e-04
# Epoch 49/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9769 - loss: 0.1148
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 49: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9769 - loss: 0.1147 - val_accuracy: 0.9915 - val_loss: 0.0674 - learning_rate: 1.0000e-04
# Epoch 50/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9739 - loss: 0.1199
# Epoch 50: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9740 - loss: 0.1197 - val_accuracy: 0.9915 - val_loss: 0.0673 - learning_rate: 2.0000e-05
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9867 - loss: 0.0816
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# Training fold 2/5
# Epoch 1/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1775 - loss: 2.3338
# Epoch 1: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.1793 - loss: 2.3262 - val_accuracy: 0.3410 - val_loss: 1.8506 - learning_rate: 1.0000e-04
# Epoch 2/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3856 - loss: 1.6288
# Epoch 2: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.3866 - loss: 1.6270 - val_accuracy: 0.5611 - val_loss: 1.6711 - learning_rate: 1.0000e-04
# Epoch 3/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5698 - loss: 1.2515
# Epoch 3: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.5715 - loss: 1.2479 - val_accuracy: 0.7352 - val_loss: 1.4564 - learning_rate: 1.0000e-04
# Epoch 4/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6450 - loss: 1.0406
# Epoch 4: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.6471 - loss: 1.0370 - val_accuracy: 0.8138 - val_loss: 1.2176 - learning_rate: 1.0000e-04
# Epoch 5/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7250 - loss: 0.8648
# Epoch 5: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.7258 - loss: 0.8633 - val_accuracy: 0.8815 - val_loss: 0.9743 - learning_rate: 1.0000e-04
# Epoch 6/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7750 - loss: 0.7377
# Epoch 6: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7755 - loss: 0.7363 - val_accuracy: 0.9069 - val_loss: 0.7662 - learning_rate: 1.0000e-04
# Epoch 7/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8092 - loss: 0.6428
# Epoch 7: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.8096 - loss: 0.6419 - val_accuracy: 0.9262 - val_loss: 0.5931 - learning_rate: 1.0000e-04
# Epoch 8/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8260 - loss: 0.5821
# Epoch 8: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8263 - loss: 0.5812 - val_accuracy: 0.9468 - val_loss: 0.4557 - learning_rate: 1.0000e-04
# Epoch 9/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8412 - loss: 0.5173
# Epoch 9: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8416 - loss: 0.5168 - val_accuracy: 0.9480 - val_loss: 0.3690 - learning_rate: 1.0000e-04
# Epoch 10/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8642 - loss: 0.4609
# Epoch 10: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.8644 - loss: 0.4604 - val_accuracy: 0.9589 - val_loss: 0.2994 - learning_rate: 1.0000e-04
# Epoch 11/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8890 - loss: 0.4071
# Epoch 11: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.8890 - loss: 0.4067 - val_accuracy: 0.9577 - val_loss: 0.2507 - learning_rate: 1.0000e-04
# Epoch 12/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8762 - loss: 0.4062
# Epoch 12: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8764 - loss: 0.4057 - val_accuracy: 0.9625 - val_loss: 0.2166 - learning_rate: 1.0000e-04
# Epoch 13/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8904 - loss: 0.3711
# Epoch 13: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8906 - loss: 0.3705 - val_accuracy: 0.9661 - val_loss: 0.1929 - learning_rate: 1.0000e-04
# Epoch 14/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9007 - loss: 0.3443
# Epoch 14: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.9010 - loss: 0.3436 - val_accuracy: 0.9722 - val_loss: 0.1750 - learning_rate: 1.0000e-04
# Epoch 15/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9123 - loss: 0.3097
# Epoch 15: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9124 - loss: 0.3095 - val_accuracy: 0.9758 - val_loss: 0.1578 - learning_rate: 1.0000e-04
# Epoch 16/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9080 - loss: 0.3075
# Epoch 16: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9086 - loss: 0.3070 - val_accuracy: 0.9758 - val_loss: 0.1470 - learning_rate: 1.0000e-04
# Epoch 17/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9140 - loss: 0.2886
# Epoch 17: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9145 - loss: 0.2879 - val_accuracy: 0.9770 - val_loss: 0.1392 - learning_rate: 1.0000e-04
# Epoch 18/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9266 - loss: 0.2781
# Epoch 18: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9268 - loss: 0.2778 - val_accuracy: 0.9794 - val_loss: 0.1342 - learning_rate: 1.0000e-04
# Epoch 19/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9387 - loss: 0.2538
# Epoch 19: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9388 - loss: 0.2534 - val_accuracy: 0.9819 - val_loss: 0.1259 - learning_rate: 1.0000e-04
# Epoch 20/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9228 - loss: 0.2587
# Epoch 20: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9230 - loss: 0.2586 - val_accuracy: 0.9831 - val_loss: 0.1218 - learning_rate: 1.0000e-04
# Epoch 21/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9341 - loss: 0.2385
# Epoch 21: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9346 - loss: 0.2380 - val_accuracy: 0.9867 - val_loss: 0.1159 - learning_rate: 1.0000e-04
# Epoch 22/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9443 - loss: 0.2132
# Epoch 22: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9444 - loss: 0.2132 - val_accuracy: 0.9879 - val_loss: 0.1097 - learning_rate: 1.0000e-04
# Epoch 23/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9411 - loss: 0.2188
# Epoch 23: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9411 - loss: 0.2188 - val_accuracy: 0.9891 - val_loss: 0.1041 - learning_rate: 1.0000e-04
# Epoch 24/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9460 - loss: 0.2102
# Epoch 24: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9460 - loss: 0.2100 - val_accuracy: 0.9855 - val_loss: 0.1046 - learning_rate: 1.0000e-04
# Epoch 25/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9518 - loss: 0.1998
# Epoch 25: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9517 - loss: 0.1999 - val_accuracy: 0.9879 - val_loss: 0.0985 - learning_rate: 1.0000e-04
# Epoch 26/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9461 - loss: 0.2095
# Epoch 26: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9464 - loss: 0.2087 - val_accuracy: 0.9891 - val_loss: 0.0960 - learning_rate: 1.0000e-04
# Epoch 27/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9467 - loss: 0.1944
# Epoch 27: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.9470 - loss: 0.1938 - val_accuracy: 0.9903 - val_loss: 0.0935 - learning_rate: 1.0000e-04
# Epoch 28/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9566 - loss: 0.1723
# Epoch 28: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9564 - loss: 0.1726 - val_accuracy: 0.9891 - val_loss: 0.0922 - learning_rate: 1.0000e-04
# Epoch 29/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9514 - loss: 0.1840
# Epoch 29: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9517 - loss: 0.1837 - val_accuracy: 0.9879 - val_loss: 0.0912 - learning_rate: 1.0000e-04
# Epoch 30/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9546 - loss: 0.1776
# Epoch 30: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9546 - loss: 0.1776 - val_accuracy: 0.9891 - val_loss: 0.0906 - learning_rate: 1.0000e-04
# Epoch 31/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9608 - loss: 0.1698
# Epoch 31: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9608 - loss: 0.1698 - val_accuracy: 0.9891 - val_loss: 0.0875 - learning_rate: 1.0000e-04
# Epoch 32/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9644 - loss: 0.1578
# Epoch 32: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9644 - loss: 0.1578 - val_accuracy: 0.9903 - val_loss: 0.0843 - learning_rate: 1.0000e-04
# Epoch 33/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9628 - loss: 0.1610
# Epoch 33: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9629 - loss: 0.1606 - val_accuracy: 0.9903 - val_loss: 0.0828 - learning_rate: 1.0000e-04
# Epoch 34/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9620 - loss: 0.1520
# Epoch 34: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9622 - loss: 0.1517 - val_accuracy: 0.9915 - val_loss: 0.0806 - learning_rate: 1.0000e-04
# Epoch 35/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9699 - loss: 0.1392
# Epoch 35: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9698 - loss: 0.1393 - val_accuracy: 0.9903 - val_loss: 0.0836 - learning_rate: 1.0000e-04
# Epoch 36/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9687 - loss: 0.1459
# Epoch 36: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.9686 - loss: 0.1458 - val_accuracy: 0.9915 - val_loss: 0.0775 - learning_rate: 1.0000e-04
# Epoch 37/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9650 - loss: 0.1426
# Epoch 37: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9651 - loss: 0.1424 - val_accuracy: 0.9891 - val_loss: 0.0809 - learning_rate: 1.0000e-04
# Epoch 38/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9777 - loss: 0.1269
# Epoch 38: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9777 - loss: 0.1269 - val_accuracy: 0.9915 - val_loss: 0.0767 - learning_rate: 1.0000e-04
# Epoch 39/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9671 - loss: 0.1377
# Epoch 39: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9671 - loss: 0.1375 - val_accuracy: 0.9903 - val_loss: 0.0783 - learning_rate: 1.0000e-04
# Epoch 40/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9755 - loss: 0.1252
# Epoch 40: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9755 - loss: 0.1253 - val_accuracy: 0.9891 - val_loss: 0.0769 - learning_rate: 1.0000e-04
# Epoch 41/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9734 - loss: 0.1276
# Epoch 41: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9733 - loss: 0.1275 - val_accuracy: 0.9903 - val_loss: 0.0753 - learning_rate: 1.0000e-04
# Epoch 42/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9685 - loss: 0.1288
# Epoch 42: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9686 - loss: 0.1286 - val_accuracy: 0.9903 - val_loss: 0.0738 - learning_rate: 1.0000e-04
# Epoch 43/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9794 - loss: 0.1126
# Epoch 43: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9792 - loss: 0.1127 - val_accuracy: 0.9903 - val_loss: 0.0714 - learning_rate: 1.0000e-04
# Epoch 44/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9813 - loss: 0.1139
# Epoch 44: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9812 - loss: 0.1136 - val_accuracy: 0.9915 - val_loss: 0.0720 - learning_rate: 1.0000e-04
# Epoch 45/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9757 - loss: 0.1102
# Epoch 45: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.9757 - loss: 0.1102 - val_accuracy: 0.9915 - val_loss: 0.0717 - learning_rate: 1.0000e-04
# Epoch 46/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9782 - loss: 0.1063
# Epoch 46: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9783 - loss: 0.1061 - val_accuracy: 0.9903 - val_loss: 0.0711 - learning_rate: 1.0000e-04
# Epoch 47/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9751 - loss: 0.1182
# Epoch 47: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9750 - loss: 0.1181 - val_accuracy: 0.9915 - val_loss: 0.0724 - learning_rate: 1.0000e-04
# Epoch 48/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9707 - loss: 0.1294
# Epoch 48: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9708 - loss: 0.1291 - val_accuracy: 0.9927 - val_loss: 0.0689 - learning_rate: 1.0000e-04
# Epoch 49/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9733 - loss: 0.1234
# Epoch 49: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9736 - loss: 0.1230 - val_accuracy: 0.9903 - val_loss: 0.0703 - learning_rate: 1.0000e-04
# Epoch 50/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9723 - loss: 0.1128
# Epoch 50: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9723 - loss: 0.1128 - val_accuracy: 0.9903 - val_loss: 0.0688 - learning_rate: 1.0000e-04
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9937 - loss: 0.0610
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Training fold 3/5
# Epoch 1/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.1567 - loss: 2.3081
# Epoch 1: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.1597 - loss: 2.2972 - val_accuracy: 0.2515 - val_loss: 1.8835 - learning_rate: 1.0000e-04
# Epoch 2/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3958 - loss: 1.6301
# Epoch 2: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.3989 - loss: 1.6249 - val_accuracy: 0.4510 - val_loss: 1.7327 - learning_rate: 1.0000e-04
# Epoch 3/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5533 - loss: 1.3040
# Epoch 3: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5553 - loss: 1.3003 - val_accuracy: 0.6493 - val_loss: 1.5357 - learning_rate: 1.0000e-04
# Epoch 4/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6819 - loss: 1.0213
# Epoch 4: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.6823 - loss: 1.0206 - val_accuracy: 0.7340 - val_loss: 1.3015 - learning_rate: 1.0000e-04
# Epoch 5/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7214 - loss: 0.8750
# Epoch 5: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.7217 - loss: 0.8744 - val_accuracy: 0.8150 - val_loss: 1.0477 - learning_rate: 1.0000e-04
# Epoch 6/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7858 - loss: 0.7207
# Epoch 6: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.7858 - loss: 0.7203 - val_accuracy: 0.8549 - val_loss: 0.8183 - learning_rate: 1.0000e-04
# Epoch 7/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8119 - loss: 0.6280
# Epoch 7: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8117 - loss: 0.6274 - val_accuracy: 0.8827 - val_loss: 0.6375 - learning_rate: 1.0000e-04
# Epoch 8/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8255 - loss: 0.5652
# Epoch 8: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8260 - loss: 0.5644 - val_accuracy: 0.8972 - val_loss: 0.4950 - learning_rate: 1.0000e-04
# Epoch 9/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8529 - loss: 0.5071
# Epoch 9: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8531 - loss: 0.5066 - val_accuracy: 0.9129 - val_loss: 0.4002 - learning_rate: 1.0000e-04
# Epoch 10/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8638 - loss: 0.4563
# Epoch 10: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8641 - loss: 0.4557 - val_accuracy: 0.9287 - val_loss: 0.3357 - learning_rate: 1.0000e-04
# Epoch 11/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8773 - loss: 0.4093
# Epoch 11: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8774 - loss: 0.4091 - val_accuracy: 0.9347 - val_loss: 0.2882 - learning_rate: 1.0000e-04
# Epoch 12/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8882 - loss: 0.3886
# Epoch 12: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.8882 - loss: 0.3885 - val_accuracy: 0.9432 - val_loss: 0.2526 - learning_rate: 1.0000e-04
# Epoch 13/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9164 - loss: 0.3249
# Epoch 13: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9163 - loss: 0.3251 - val_accuracy: 0.9480 - val_loss: 0.2266 - learning_rate: 1.0000e-04
# Epoch 14/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9257 - loss: 0.3041
# Epoch 14: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9253 - loss: 0.3047 - val_accuracy: 0.9553 - val_loss: 0.2081 - learning_rate: 1.0000e-04
# Epoch 15/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9171 - loss: 0.3049
# Epoch 15: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9173 - loss: 0.3046 - val_accuracy: 0.9541 - val_loss: 0.1957 - learning_rate: 1.0000e-04
# Epoch 16/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9187 - loss: 0.2992
# Epoch 16: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9188 - loss: 0.2986 - val_accuracy: 0.9577 - val_loss: 0.1841 - learning_rate: 1.0000e-04
# Epoch 17/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9310 - loss: 0.2801
# Epoch 17: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9308 - loss: 0.2796 - val_accuracy: 0.9589 - val_loss: 0.1765 - learning_rate: 1.0000e-04
# Epoch 18/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9327 - loss: 0.2605
# Epoch 18: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9327 - loss: 0.2604 - val_accuracy: 0.9625 - val_loss: 0.1677 - learning_rate: 1.0000e-04
# Epoch 19/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9243 - loss: 0.2564
# Epoch 19: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9247 - loss: 0.2558 - val_accuracy: 0.9661 - val_loss: 0.1622 - learning_rate: 1.0000e-04
# Epoch 20/50
# ...
# Epoch 50: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9749 - loss: 0.1257 - val_accuracy: 0.9855 - val_loss: 0.0820 - learning_rate: 1.0000e-04
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9803 - loss: 0.0950
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# Training fold 5/5
# Epoch 1/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.2012 - loss: 2.2373
# Epoch 1: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.2029 - loss: 2.2299 - val_accuracy: 0.2772 - val_loss: 1.9085 - learning_rate: 1.0000e-04
# Epoch 2/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4047 - loss: 1.6386
# Epoch 2: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.4065 - loss: 1.6343 - val_accuracy: 0.4274 - val_loss: 1.7644 - learning_rate: 1.0000e-04
# Epoch 3/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5584 - loss: 1.2767
# Epoch 3: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.5602 - loss: 1.2725 - val_accuracy: 0.5944 - val_loss: 1.5770 - learning_rate: 1.0000e-04
# Epoch 4/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6721 - loss: 1.0257
# Epoch 4: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.6734 - loss: 1.0224 - val_accuracy: 0.7506 - val_loss: 1.3445 - learning_rate: 1.0000e-04
# Epoch 5/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7288 - loss: 0.8643
# Epoch 5: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7292 - loss: 0.8634 - val_accuracy: 0.8378 - val_loss: 1.0838 - learning_rate: 1.0000e-04
# Epoch 6/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7822 - loss: 0.7366
# Epoch 6: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.7824 - loss: 0.7355 - val_accuracy: 0.8680 - val_loss: 0.8451 - learning_rate: 1.0000e-04
# Epoch 7/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7856 - loss: 0.6733
# Epoch 7: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.7862 - loss: 0.6717 - val_accuracy: 0.9189 - val_loss: 0.6376 - learning_rate: 1.0000e-04
# Epoch 8/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8387 - loss: 0.5658
# Epoch 8: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8391 - loss: 0.5648 - val_accuracy: 0.9310 - val_loss: 0.4868 - learning_rate: 1.0000e-04
# Epoch 9/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8525 - loss: 0.5055
# Epoch 9: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8527 - loss: 0.5049 - val_accuracy: 0.9419 - val_loss: 0.3848 - learning_rate: 1.0000e-04
# Epoch 10/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8598 - loss: 0.4685
# Epoch 10: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8601 - loss: 0.4676 - val_accuracy: 0.9419 - val_loss: 0.3157 - learning_rate: 1.0000e-04
# Epoch 11/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8844 - loss: 0.4197
# Epoch 11: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8844 - loss: 0.4194 - val_accuracy: 0.9479 - val_loss: 0.2675 - learning_rate: 1.0000e-04
# Epoch 12/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8952 - loss: 0.3811
# Epoch 12: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.8952 - loss: 0.3806 - val_accuracy: 0.9528 - val_loss: 0.2344 - learning_rate: 1.0000e-04
# Epoch 13/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9014 - loss: 0.3620
# Epoch 13: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9013 - loss: 0.3621 - val_accuracy: 0.9600 - val_loss: 0.2104 - learning_rate: 1.0000e-04
# Epoch 14/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9061 - loss: 0.3565
# Epoch 14: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9063 - loss: 0.3551 - val_accuracy: 0.9613 - val_loss: 0.1945 - learning_rate: 1.0000e-04
# Epoch 15/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9163 - loss: 0.3215
# Epoch 15: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.9164 - loss: 0.3210 - val_accuracy: 0.9649 - val_loss: 0.1800 - learning_rate: 1.0000e-04
# Epoch 16/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9240 - loss: 0.2971
# Epoch 16: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9237 - loss: 0.2973 - val_accuracy: 0.9673 - val_loss: 0.1702 - learning_rate: 1.0000e-04
# Epoch 17/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9133 - loss: 0.3099
# Epoch 17: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9134 - loss: 0.3091 - val_accuracy: 0.9697 - val_loss: 0.1590 - learning_rate: 1.0000e-04
# Epoch 18/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9329 - loss: 0.2664
# Epoch 18: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9329 - loss: 0.2662 - val_accuracy: 0.9697 - val_loss: 0.1489 - learning_rate: 1.0000e-04
# Epoch 19/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9363 - loss: 0.2721
# Epoch 19: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9361 - loss: 0.2718 - val_accuracy: 0.9722 - val_loss: 0.1428 - learning_rate: 1.0000e-04
# Epoch 20/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9402 - loss: 0.2470
# Epoch 20: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9400 - loss: 0.2469 - val_accuracy: 0.9709 - val_loss: 0.1364 - learning_rate: 1.0000e-04
# Epoch 21/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9348 - loss: 0.2550
# Epoch 21: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9348 - loss: 0.2543 - val_accuracy: 0.9734 - val_loss: 0.1319 - learning_rate: 1.0000e-04
# Epoch 22/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9433 - loss: 0.2303
# Epoch 22: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9434 - loss: 0.2299 - val_accuracy: 0.9746 - val_loss: 0.1288 - learning_rate: 1.0000e-04
# Epoch 23/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9453 - loss: 0.2282
# Epoch 23: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9453 - loss: 0.2280 - val_accuracy: 0.9770 - val_loss: 0.1214 - learning_rate: 1.0000e-04
# Epoch 24/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9411 - loss: 0.2232
# Epoch 24: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9411 - loss: 0.2229 - val_accuracy: 0.9794 - val_loss: 0.1177 - learning_rate: 1.0000e-04
# Epoch 25/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9479 - loss: 0.2004
# Epoch 25: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.9479 - loss: 0.2002 - val_accuracy: 0.9843 - val_loss: 0.1140 - learning_rate: 1.0000e-04
# Epoch 26/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9514 - loss: 0.2025
# Epoch 26: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.9512 - loss: 0.2024 - val_accuracy: 0.9831 - val_loss: 0.1095 - learning_rate: 1.0000e-04
# Epoch 27/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9497 - loss: 0.2061
# Epoch 27: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9497 - loss: 0.2055 - val_accuracy: 0.9867 - val_loss: 0.1047 - learning_rate: 1.0000e-04
# Epoch 28/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9575 - loss: 0.1772
# Epoch 28: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9575 - loss: 0.1770 - val_accuracy: 0.9879 - val_loss: 0.1016 - learning_rate: 1.0000e-04
# Epoch 29/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9592 - loss: 0.1832
# Epoch 29: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9592 - loss: 0.1831 - val_accuracy: 0.9867 - val_loss: 0.0993 - learning_rate: 1.0000e-04
# Epoch 30/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9617 - loss: 0.1753
# Epoch 30: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.9617 - loss: 0.1754 - val_accuracy: 0.9903 - val_loss: 0.0951 - learning_rate: 1.0000e-04
# Epoch 31/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9580 - loss: 0.1803
# Epoch 31: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9581 - loss: 0.1801 - val_accuracy: 0.9903 - val_loss: 0.0940 - learning_rate: 1.0000e-04
# Epoch 32/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9645 - loss: 0.1709
# Epoch 32: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9646 - loss: 0.1702 - val_accuracy: 0.9927 - val_loss: 0.0916 - learning_rate: 1.0000e-04
# Epoch 33/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9656 - loss: 0.1640
# Epoch 33: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9656 - loss: 0.1640 - val_accuracy: 0.9927 - val_loss: 0.0882 - learning_rate: 1.0000e-04
# Epoch 34/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9622 - loss: 0.1644
# Epoch 34: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9622 - loss: 0.1643 - val_accuracy: 0.9891 - val_loss: 0.0889 - learning_rate: 1.0000e-04
# Epoch 35/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9656 - loss: 0.1583
# Epoch 35: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9657 - loss: 0.1580 - val_accuracy: 0.9927 - val_loss: 0.0865 - learning_rate: 1.0000e-04
# Epoch 36/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9704 - loss: 0.1438
# Epoch 36: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.9704 - loss: 0.1438 - val_accuracy: 0.9927 - val_loss: 0.0857 - learning_rate: 1.0000e-04
# Epoch 37/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9584 - loss: 0.1673
# Epoch 37: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9585 - loss: 0.1667 - val_accuracy: 0.9915 - val_loss: 0.0837 - learning_rate: 1.0000e-04
# Epoch 38/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9665 - loss: 0.1506
# Epoch 38: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9665 - loss: 0.1505 - val_accuracy: 0.9927 - val_loss: 0.0820 - learning_rate: 1.0000e-04
# Epoch 39/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9667 - loss: 0.1424
# Epoch 39: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9668 - loss: 0.1421 - val_accuracy: 0.9927 - val_loss: 0.0793 - learning_rate: 1.0000e-04
# Epoch 40/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9696 - loss: 0.1446
# Epoch 40: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9698 - loss: 0.1443 - val_accuracy: 0.9915 - val_loss: 0.0786 - learning_rate: 1.0000e-04
# Epoch 41/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9717 - loss: 0.1333
# Epoch 41: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9717 - loss: 0.1332 - val_accuracy: 0.9927 - val_loss: 0.0783 - learning_rate: 1.0000e-04
# Epoch 42/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9686 - loss: 0.1387
# Epoch 42: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.9686 - loss: 0.1386 - val_accuracy: 0.9903 - val_loss: 0.0777 - learning_rate: 1.0000e-04
# Epoch 43/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9763 - loss: 0.1319
# Epoch 43: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9762 - loss: 0.1316 - val_accuracy: 0.9915 - val_loss: 0.0750 - learning_rate: 1.0000e-04
# Epoch 44/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9744 - loss: 0.1131
# Epoch 44: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9745 - loss: 0.1134 - val_accuracy: 0.9927 - val_loss: 0.0737 - learning_rate: 1.0000e-04
# Epoch 45/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9723 - loss: 0.1309
# Epoch 45: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9725 - loss: 0.1305 - val_accuracy: 0.9927 - val_loss: 0.0751 - learning_rate: 1.0000e-04
# Epoch 46/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9721 - loss: 0.1256
# Epoch 46: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9721 - loss: 0.1253 - val_accuracy: 0.9939 - val_loss: 0.0704 - learning_rate: 1.0000e-04
# Epoch 47/50
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9740 - loss: 0.1210
# Epoch 47: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.9740 - loss: 0.1208 - val_accuracy: 0.9927 - val_loss: 0.0676 - learning_rate: 1.0000e-04
# Epoch 48/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9757 - loss: 0.1203
# Epoch 48: val_loss did not improve from 0.06725
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.9757 - loss: 0.1201 - val_accuracy: 0.9939 - val_loss: 0.0677 - learning_rate: 1.0000e-04
# Epoch 49/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9750 - loss: 0.1139
# Epoch 49: val_loss improved from 0.06725 to 0.06672, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9750 - loss: 0.1139 - val_accuracy: 0.9939 - val_loss: 0.0667 - learning_rate: 1.0000e-04
# Epoch 50/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9767 - loss: 0.1144
# Epoch 50: val_loss improved from 0.06672 to 0.06613, saving model to model/best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9767 - loss: 0.1144 - val_accuracy: 0.9939 - val_loss: 0.0661 - learning_rate: 1.0000e-04
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9947 - loss: 0.0642
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       600
#            1       0.97      0.99      0.98       600
#            2       1.00      0.99      1.00       542
#            3       0.99      0.99      0.99       600
#            4       0.99      0.98      0.98       600
#            5       0.99      0.99      0.99       597
#            6       0.99      0.99      0.99       594
#
#     accuracy                           0.99      4133
#    macro avg       0.99      0.99      0.99      4133
# weighted avg       0.99      0.99      0.99      4133
#
#
# Average validation accuracy: 0.9894 ± 0.0039
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
#
# Test Query: How do I properly dispose of electronic waste?
# Predicted Intent: 3R Tips
# Confidence: 0.98
