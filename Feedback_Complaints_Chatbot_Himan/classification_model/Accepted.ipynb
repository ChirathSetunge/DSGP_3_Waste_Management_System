# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split, KFold
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import (
    Embedding, Bidirectional, LSTM, Dense, Dropout,
    BatchNormalization, SpatialDropout1D, Conv1D,
    MaxPooling1D, GlobalMaxPooling1D, concatenate,
    Input, Add
)
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
import re
import warnings
import os
from sklearn.metrics import confusion_matrix, classification_report
import itertools

np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

GLOVE_EMBEDDINGS_PATH = 'glove.6B.100d.txt'
MODEL_SAVE_PATH = 'best_intent_model.h5'

def load_and_preprocess_data(file_path):
    data = pd.read_excel(file_path)
    print("Dataset shape:", data.shape)
    print("\nClass distribution:")
    print(data['Category'].value_counts())
    return data

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)
    return text.strip()

def prepare_text_data(data):
    data['Query'] = data['Query'].apply(clean_text)

    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(data['Query'])

    sequences = tokenizer.texts_to_sequences(data['Query'])
    max_sequence_length = max(len(seq) for seq in sequences)
    X = pad_sequences(sequences, maxlen=max_sequence_length, padding='post')

    intent_labels = list(set(data['Category']))
    intent_to_index = {intent: i for i, intent in enumerate(intent_labels)}
    y = np.array([intent_to_index[intent] for intent in data['Category']])

    return X, y, tokenizer, max_sequence_length, intent_labels, intent_to_index

def augment_text(text, max_augmented=2):
    augmented = [text]
    words = text.split()

    if len(words) > 3:
        dropped = words.copy()
        drop_idx = np.random.randint(0, len(words))
        dropped.pop(drop_idx)
        augmented.append(' '.join(dropped))

    if len(words) > 3:
        shuffled = words.copy()
        np.random.shuffle(shuffled)
        augmented.append(' '.join(shuffled))

    return augmented[:max_augmented]

def augment_dataset(X, y, tokenizer, max_sequence_length):
    augmented_texts = []
    augmented_labels = []

    original_texts = []
    for seq in X:
        text = []
        for idx in seq:
            if idx != 0:
                for word, word_idx in tokenizer.word_index.items():
                    if word_idx == idx:
                        text.append(word)
                        break
        original_texts.append(' '.join(text))

    for text, label in zip(original_texts, y):
        aug_texts = augment_text(text)
        augmented_texts.extend(aug_texts)
        augmented_labels.extend([label] * len(aug_texts))

    aug_sequences = tokenizer.texts_to_sequences(augmented_texts)
    X_aug = pad_sequences(aug_sequences, maxlen=max_sequence_length, padding='post')
    y_aug = np.array(augmented_labels)

    return X_aug, y_aug

def load_glove_embeddings(word_index, embedding_dim=94):
    if not os.path.exists(GLOVE_EMBEDDINGS_PATH):
        print(f"Warning: GloVe embeddings file {GLOVE_EMBEDDINGS_PATH} not found.")
        return None

    embeddings_index = {}
    try:
        with open(GLOVE_EMBEDDINGS_PATH, encoding='utf-8') as f:
            first_line = next(f)
            actual_dim = len(first_line.split()) - 1
            if actual_dim != embedding_dim:
                print(f"Warning: Expected embedding dimension {embedding_dim} but found {actual_dim}")
                embedding_dim = actual_dim

            f.seek(0)

            for line in f:
                values = line.split()
                word = values[0]
                coefs = np.asarray(values[1:], dtype='float32')
                embeddings_index[word] = coefs

        embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
        for word, i in word_index.items():
            embedding_vector = embeddings_index.get(word)
            if embedding_vector is not None:
                embedding_matrix[i] = embedding_vector

        return embedding_matrix
    except Exception as e:
        print(f"Error loading GloVe embeddings: {e}")
        return None

def create_enhanced_model(vocab_size, embedding_dim, max_sequence_length, num_classes, embedding_matrix=None):

    input_layer = Input(shape=(max_sequence_length,))

    embedding = Embedding(
        input_dim=vocab_size,
        output_dim=embedding_dim,
        input_length=max_sequence_length,
        weights=[embedding_matrix] if embedding_matrix is not None else None,
        trainable=False if embedding_matrix is not None else True
    )(input_layer)

    embedding_dropout = SpatialDropout1D(0.2)(embedding)

    conv1 = Conv1D(128, 3, activation='relu', padding='same')(embedding_dropout)
    pool1 = MaxPooling1D(2)(conv1)
    conv2 = Conv1D(64, 3, activation='relu', padding='same')(pool1)
    global_pool1 = GlobalMaxPooling1D()(conv2)

    conv3 = Conv1D(128, 5, activation='relu', padding='same')(embedding_dropout)
    pool2 = MaxPooling1D(2)(conv3)
    conv4 = Conv1D(64, 5, activation='relu', padding='same')(pool2)
    global_pool2 = GlobalMaxPooling1D()(conv4)

    lstm1 = Bidirectional(LSTM(128, return_sequences=True,
                              kernel_regularizer=l2(1e-4)))(embedding_dropout)
    bn1 = BatchNormalization()(lstm1)
    lstm2 = Bidirectional(LSTM(64, return_sequences=False,
                              kernel_regularizer=l2(1e-4)))(bn1)
    bn2 = BatchNormalization()(lstm2)

    merged = concatenate([global_pool1, global_pool2, bn2])

    dense1 = Dense(128, activation='relu', kernel_regularizer=l2(1e-4))(merged)
    dropout1 = Dropout(0.4)(dense1)
    bn3 = BatchNormalization()(dropout1)

    dense2 = Dense(64, activation='relu', kernel_regularizer=l2(1e-4))(bn3)
    dropout2 = Dropout(0.3)(dense2)
    bn4 = BatchNormalization()(dropout2)

    output_layer = Dense(num_classes, activation='softmax')(bn4)

    model = Model(inputs=input_layer, outputs=output_layer)

    optimizer = Adam(
        learning_rate=0.0001,
        clipnorm=1.0,
        beta_1=0.9,
        beta_2=0.999,
        epsilon=1e-7
    )

    model.compile(
        optimizer=optimizer,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

def get_enhanced_training_config():
    return {
        'batch_size': 64,
        'epochs': 150,
        'callbacks': [
            EarlyStopping(
                monitor='val_loss',
                patience=8,
                restore_best_weights=True,
                min_delta=1e-5
            ),
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.2,
                patience=5,
                min_lr=1e-7,
                verbose=1
            ),
            ModelCheckpoint(
                MODEL_SAVE_PATH,
                monitor='val_loss',
                save_best_only=True,
                verbose=1
            )
        ]
    }

def plot_confusion_matrix(y_true, y_pred, classes, normalize=False, title='Confusion Matrix'):
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='.2f' if normalize else 'd',
                cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.title(title)
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.show()

def plot_training_metrics(history, fold=None):
    metrics = ['loss', 'accuracy' if 'accuracy' in history.history else 'acc']

    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    fig.suptitle(f'Training Metrics {f"(Fold {fold})" if fold else ""}')

    for idx, metric in enumerate(metrics):
        axes[idx].plot(history.history[metric], label='Train')
        axes[idx].plot(history.history.get(f'val_{metric}', []), label='Validation')
        axes[idx].set_title(f'Model {metric.capitalize()}')
        axes[idx].set_xlabel('Epoch')
        axes[idx].set_ylabel(metric.capitalize())
        axes[idx].legend()

    plt.tight_layout()
    plt.show()

def train_enhanced_model(X, y, vocab_size, embedding_dim, max_sequence_length,
                         num_classes, embedding_matrix=None, n_splits=5):
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    fold_scores = []
    training_config = get_enhanced_training_config()
    all_predictions = []
    all_true_labels = []

    for fold, (train_idx, val_idx) in enumerate(kfold.split(X)):
        print(f'\nTraining fold {fold + 1}/{n_splits}')

        # Split data
        X_fold_train, y_fold_train = X[train_idx], y[train_idx]
        X_fold_val, y_fold_val = X[val_idx], y[val_idx]

        class_weights = compute_class_weight(
            class_weight="balanced",
            classes=np.unique(y_fold_train),
            y=y_fold_train
        )
        class_weight_dict = dict(enumerate(class_weights))

        model = create_enhanced_model(
            vocab_size, embedding_dim, max_sequence_length,
            num_classes, embedding_matrix
        )

        history = model.fit(
            X_fold_train, y_fold_train,
            validation_data=(X_fold_val, y_fold_val),
            class_weight=class_weight_dict,
            **training_config
        )

        val_loss, val_acc = model.evaluate(X_fold_val, y_fold_val)
        fold_scores.append(val_acc)

        y_pred = np.argmax(model.predict(X_fold_val), axis=1)
        all_predictions.extend(y_pred)
        all_true_labels.extend(y_fold_val)

        plot_training_metrics(history, fold + 1)

    plot_confusion_matrix(
        all_true_labels, all_predictions,
        classes=range(num_classes),
        normalize=True,
        title='Overall Normalized Confusion Matrix'
    )

    print(f'\nClassification Report:')
    print(classification_report(all_true_labels, all_predictions))
    print(f'\nAverage validation accuracy: {np.mean(fold_scores):.4f} ± {np.std(fold_scores):.4f}')

    return fold_scores

def predict_intent(text, model, tokenizer, max_sequence_length, intent_labels):
    cleaned_text = clean_text(text)
    sequence = tokenizer.texts_to_sequences([cleaned_text])
    padded_sequence = pad_sequences(sequence, maxlen=max_sequence_length, padding='post')

    prediction = model.predict(padded_sequence)
    predicted_class = np.argmax(prediction[0])
    confidence = prediction[0][predicted_class]

    return intent_labels[predicted_class], confidence

def main():
    data = load_and_preprocess_data("shuffled_text_queries.xlsx")
    X, y, tokenizer, max_sequence_length, intent_labels, intent_to_index = prepare_text_data(data)

    embedding_dim = 100
    vocab_size = len(tokenizer.word_index) + 1
    num_classes = len(intent_labels)
    embedding_matrix = load_glove_embeddings(tokenizer.word_index, embedding_dim)

    X_aug, y_aug = augment_dataset(X, y, tokenizer, max_sequence_length)

    fold_scores = train_enhanced_model(
        X_aug, y_aug,
        vocab_size, embedding_dim, max_sequence_length,
        num_classes, embedding_matrix
    )

    if os.path.exists(MODEL_SAVE_PATH):
        best_model = load_model(MODEL_SAVE_PATH)
        test_query = "How do I properly dispose of electronic waste?"
        intent, confidence = predict_intent(
            test_query, best_model, tokenizer,
            max_sequence_length, intent_labels
        )
        print(f"\nTest Query: {test_query}")
        print(f"Predicted Intent: {intent}")
        print(f"Confidence: {confidence:.2f}")
    else:
        print("No saved model found. Please train the model first.")

    return tokenizer, intent_labels, intent_to_index

if __name__ == "__main__":
    main()
# Out:
# Dataset shape: (500, 2)
#
# Class distribution:
# Category
# 3R Tips                       100
# Waste collection schedules    100
# Complaints                    100
# Public Awareness Tips         100
# Feedback                      100
# Name: count, dtype: int64
#
# Training fold 1/5
# Epoch 1/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.2150 - loss: 2.2340
# Epoch 1: val_loss improved from inf to 1.71603, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 331ms/step - accuracy: 0.2152 - loss: 2.2338 - val_accuracy: 0.2650 - val_loss: 1.7160 - learning_rate: 1.0000e-04
# Epoch 2/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.2388 - loss: 2.1135
# Epoch 2: val_loss improved from 1.71603 to 1.69632, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 230ms/step - accuracy: 0.2404 - loss: 2.1116 - val_accuracy: 0.2900 - val_loss: 1.6963 - learning_rate: 1.0000e-04
# Epoch 3/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.2990 - loss: 1.8978
# Epoch 3: val_loss improved from 1.69632 to 1.67940, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.2995 - loss: 1.8982 - val_accuracy: 0.3500 - val_loss: 1.6794 - learning_rate: 1.0000e-04
# Epoch 4/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.3131 - loss: 1.8566
# Epoch 4: val_loss improved from 1.67940 to 1.66823, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 224ms/step - accuracy: 0.3132 - loss: 1.8559 - val_accuracy: 0.3500 - val_loss: 1.6682 - learning_rate: 1.0000e-04
# Epoch 5/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.3320 - loss: 1.8097
# Epoch 5: val_loss improved from 1.66823 to 1.65634, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 351ms/step - accuracy: 0.3322 - loss: 1.8090 - val_accuracy: 0.3550 - val_loss: 1.6563 - learning_rate: 1.0000e-04
# Epoch 6/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.3622 - loss: 1.7147
# Epoch 6: val_loss improved from 1.65634 to 1.64543, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - accuracy: 0.3626 - loss: 1.7133 - val_accuracy: 0.3600 - val_loss: 1.6454 - learning_rate: 1.0000e-04
# Epoch 7/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.4251 - loss: 1.5950
# Epoch 7: val_loss improved from 1.64543 to 1.63245, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - accuracy: 0.4235 - loss: 1.5993 - val_accuracy: 0.3600 - val_loss: 1.6324 - learning_rate: 1.0000e-04
# Epoch 8/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.3836 - loss: 1.6039
# Epoch 8: val_loss improved from 1.63245 to 1.60749, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 289ms/step - accuracy: 0.3837 - loss: 1.6020 - val_accuracy: 0.3750 - val_loss: 1.6075 - learning_rate: 1.0000e-04
# Epoch 9/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.3631 - loss: 1.6108
# Epoch 9: val_loss improved from 1.60749 to 1.58787, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 356ms/step - accuracy: 0.3650 - loss: 1.6093 - val_accuracy: 0.3750 - val_loss: 1.5879 - learning_rate: 1.0000e-04
# Epoch 10/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.4693 - loss: 1.4318
# Epoch 10: val_loss improved from 1.58787 to 1.56229, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.4685 - loss: 1.4338 - val_accuracy: 0.3900 - val_loss: 1.5623 - learning_rate: 1.0000e-04
# Epoch 11/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.4604 - loss: 1.4596
# Epoch 11: val_loss improved from 1.56229 to 1.53607, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - accuracy: 0.4591 - loss: 1.4629 - val_accuracy: 0.4300 - val_loss: 1.5361 - learning_rate: 1.0000e-04
# Epoch 12/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.4512 - loss: 1.4301
# Epoch 12: val_loss improved from 1.53607 to 1.51316, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 292ms/step - accuracy: 0.4501 - loss: 1.4324 - val_accuracy: 0.4500 - val_loss: 1.5132 - learning_rate: 1.0000e-04
# Epoch 13/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.4389 - loss: 1.4585
# Epoch 13: val_loss improved from 1.51316 to 1.49111, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.4379 - loss: 1.4576 - val_accuracy: 0.4650 - val_loss: 1.4911 - learning_rate: 1.0000e-04
# Epoch 14/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.4854 - loss: 1.4217
# Epoch 14: val_loss improved from 1.49111 to 1.45958, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - accuracy: 0.4864 - loss: 1.4198 - val_accuracy: 0.4800 - val_loss: 1.4596 - learning_rate: 1.0000e-04
# Epoch 15/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.5113 - loss: 1.3515
# Epoch 15: val_loss improved from 1.45958 to 1.42011, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - accuracy: 0.5107 - loss: 1.3535 - val_accuracy: 0.5200 - val_loss: 1.4201 - learning_rate: 1.0000e-04
# Epoch 16/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.4983 - loss: 1.3650
# Epoch 16: val_loss improved from 1.42011 to 1.38429, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - accuracy: 0.4989 - loss: 1.3621 - val_accuracy: 0.5300 - val_loss: 1.3843 - learning_rate: 1.0000e-04
# Epoch 17/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.5064 - loss: 1.3005
# Epoch 17: val_loss improved from 1.38429 to 1.34459, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 413ms/step - accuracy: 0.5068 - loss: 1.3003 - val_accuracy: 0.5400 - val_loss: 1.3446 - learning_rate: 1.0000e-04
# Epoch 18/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.5252 - loss: 1.2867
# Epoch 18: val_loss improved from 1.34459 to 1.30445, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.5258 - loss: 1.2860 - val_accuracy: 0.5500 - val_loss: 1.3045 - learning_rate: 1.0000e-04
# Epoch 19/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.5359 - loss: 1.2456
# Epoch 19: val_loss improved from 1.30445 to 1.26731, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - accuracy: 0.5353 - loss: 1.2470 - val_accuracy: 0.5650 - val_loss: 1.2673 - learning_rate: 1.0000e-04
# Epoch 20/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.5556 - loss: 1.1889
# Epoch 20: val_loss improved from 1.26731 to 1.23707, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 336ms/step - accuracy: 0.5556 - loss: 1.1901 - val_accuracy: 0.5600 - val_loss: 1.2371 - learning_rate: 1.0000e-04
# Epoch 21/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.5368 - loss: 1.1966
# Epoch 21: val_loss improved from 1.23707 to 1.20963, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - accuracy: 0.5372 - loss: 1.1972 - val_accuracy: 0.5650 - val_loss: 1.2096 - learning_rate: 1.0000e-04
# Epoch 22/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.5533 - loss: 1.1968
# Epoch 22: val_loss improved from 1.20963 to 1.18408, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.5545 - loss: 1.1958 - val_accuracy: 0.5750 - val_loss: 1.1841 - learning_rate: 1.0000e-04
# Epoch 23/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.5493 - loss: 1.1253
# Epoch 23: val_loss improved from 1.18408 to 1.14878, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.5497 - loss: 1.1256 - val_accuracy: 0.5850 - val_loss: 1.1488 - learning_rate: 1.0000e-04
# Epoch 24/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.5684 - loss: 1.1574
# Epoch 24: val_loss improved from 1.14878 to 1.11892, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.5693 - loss: 1.1569 - val_accuracy: 0.5950 - val_loss: 1.1189 - learning_rate: 1.0000e-04
# Epoch 25/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.5670 - loss: 1.1577
# Epoch 25: val_loss improved from 1.11892 to 1.08080, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - accuracy: 0.5663 - loss: 1.1562 - val_accuracy: 0.6000 - val_loss: 1.0808 - learning_rate: 1.0000e-04
# Epoch 26/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.5803 - loss: 1.0816
# Epoch 26: val_loss improved from 1.08080 to 1.03088, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 279ms/step - accuracy: 0.5809 - loss: 1.0816 - val_accuracy: 0.6150 - val_loss: 1.0309 - learning_rate: 1.0000e-04
# Epoch 27/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.6231 - loss: 1.0130
# Epoch 27: val_loss improved from 1.03088 to 0.99321, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.6223 - loss: 1.0151 - val_accuracy: 0.6200 - val_loss: 0.9932 - learning_rate: 1.0000e-04
# Epoch 28/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.6286 - loss: 1.0435
# Epoch 28: val_loss improved from 0.99321 to 0.95407, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 232ms/step - accuracy: 0.6278 - loss: 1.0437 - val_accuracy: 0.6350 - val_loss: 0.9541 - learning_rate: 1.0000e-04
# Epoch 29/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.5794 - loss: 1.1017
# Epoch 29: val_loss improved from 0.95407 to 0.91785, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.5801 - loss: 1.1014 - val_accuracy: 0.6650 - val_loss: 0.9178 - learning_rate: 1.0000e-04
# Epoch 30/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.6168 - loss: 1.0438
# Epoch 30: val_loss improved from 0.91785 to 0.89085, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 307ms/step - accuracy: 0.6184 - loss: 1.0424 - val_accuracy: 0.6750 - val_loss: 0.8909 - learning_rate: 1.0000e-04
# Epoch 31/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.6226 - loss: 1.0460
# Epoch 31: val_loss improved from 0.89085 to 0.86292, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - accuracy: 0.6232 - loss: 1.0430 - val_accuracy: 0.6850 - val_loss: 0.8629 - learning_rate: 1.0000e-04
# Epoch 32/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.6553 - loss: 0.9721
# Epoch 32: val_loss improved from 0.86292 to 0.84496, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - accuracy: 0.6558 - loss: 0.9710 - val_accuracy: 0.6750 - val_loss: 0.8450 - learning_rate: 1.0000e-04
# Epoch 33/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6062 - loss: 1.0239
# Epoch 33: val_loss improved from 0.84496 to 0.82428, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 300ms/step - accuracy: 0.6085 - loss: 1.0208 - val_accuracy: 0.6800 - val_loss: 0.8243 - learning_rate: 1.0000e-04
# Epoch 34/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.6447 - loss: 0.9249
# Epoch 34: val_loss improved from 0.82428 to 0.80191, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - accuracy: 0.6444 - loss: 0.9261 - val_accuracy: 0.6900 - val_loss: 0.8019 - learning_rate: 1.0000e-04
# Epoch 35/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.6276 - loss: 0.9775
# Epoch 35: val_loss improved from 0.80191 to 0.77228, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - accuracy: 0.6270 - loss: 0.9779 - val_accuracy: 0.7150 - val_loss: 0.7723 - learning_rate: 1.0000e-04
# Epoch 36/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.6562 - loss: 0.9530
# Epoch 36: val_loss improved from 0.77228 to 0.75841, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.6556 - loss: 0.9522 - val_accuracy: 0.7400 - val_loss: 0.7584 - learning_rate: 1.0000e-04
# Epoch 37/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.6448 - loss: 0.9405
# Epoch 37: val_loss improved from 0.75841 to 0.73937, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.6442 - loss: 0.9416 - val_accuracy: 0.7300 - val_loss: 0.7394 - learning_rate: 1.0000e-04
# Epoch 38/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.6635 - loss: 0.9111
# Epoch 38: val_loss did not improve from 0.73937
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - accuracy: 0.6652 - loss: 0.9101 - val_accuracy: 0.7450 - val_loss: 0.7398 - learning_rate: 1.0000e-04
# Epoch 39/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6949 - loss: 0.8274
# Epoch 39: val_loss improved from 0.73937 to 0.72665, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - accuracy: 0.6939 - loss: 0.8306 - val_accuracy: 0.7400 - val_loss: 0.7266 - learning_rate: 1.0000e-04
# Epoch 40/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.6641 - loss: 0.8618
# Epoch 40: val_loss improved from 0.72665 to 0.70051, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 271ms/step - accuracy: 0.6643 - loss: 0.8632 - val_accuracy: 0.7400 - val_loss: 0.7005 - learning_rate: 1.0000e-04
# Epoch 41/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.7114 - loss: 0.8689
# Epoch 41: val_loss did not improve from 0.70051
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - accuracy: 0.7102 - loss: 0.8682 - val_accuracy: 0.7400 - val_loss: 0.7042 - learning_rate: 1.0000e-04
# Epoch 42/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.7050 - loss: 0.8327
# Epoch 42: val_loss did not improve from 0.70051
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.7053 - loss: 0.8315 - val_accuracy: 0.7400 - val_loss: 0.7043 - learning_rate: 1.0000e-04
# Epoch 43/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.6898 - loss: 0.8190
# Epoch 43: val_loss improved from 0.70051 to 0.69068, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - accuracy: 0.6901 - loss: 0.8201 - val_accuracy: 0.7550 - val_loss: 0.6907 - learning_rate: 1.0000e-04
# Epoch 44/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7025 - loss: 0.8583
# Epoch 44: val_loss improved from 0.69068 to 0.68655, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.7038 - loss: 0.8554 - val_accuracy: 0.7500 - val_loss: 0.6865 - learning_rate: 1.0000e-04
# Epoch 45/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.6855 - loss: 0.8615
# Epoch 45: val_loss improved from 0.68655 to 0.66364, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.6857 - loss: 0.8611 - val_accuracy: 0.7550 - val_loss: 0.6636 - learning_rate: 1.0000e-04
# Epoch 46/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.7556 - loss: 0.7484
# Epoch 46: val_loss improved from 0.66364 to 0.65587, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 318ms/step - accuracy: 0.7547 - loss: 0.7510 - val_accuracy: 0.7700 - val_loss: 0.6559 - learning_rate: 1.0000e-04
# Epoch 47/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7257 - loss: 0.7833
# Epoch 47: val_loss improved from 0.65587 to 0.64766, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.7254 - loss: 0.7832 - val_accuracy: 0.7600 - val_loss: 0.6477 - learning_rate: 1.0000e-04
# Epoch 48/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.7308 - loss: 0.7687
# Epoch 48: val_loss improved from 0.64766 to 0.64029, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 220ms/step - accuracy: 0.7297 - loss: 0.7697 - val_accuracy: 0.7550 - val_loss: 0.6403 - learning_rate: 1.0000e-04
# Epoch 49/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.7367 - loss: 0.7635
# Epoch 49: val_loss improved from 0.64029 to 0.64007, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 306ms/step - accuracy: 0.7353 - loss: 0.7648 - val_accuracy: 0.7400 - val_loss: 0.6401 - learning_rate: 1.0000e-04
# Epoch 50/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.7194 - loss: 0.7723
# Epoch 50: val_loss improved from 0.64007 to 0.63164, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.7197 - loss: 0.7721 - val_accuracy: 0.7450 - val_loss: 0.6316 - learning_rate: 1.0000e-04
# Epoch 51/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7436 - loss: 0.7217
# Epoch 51: val_loss improved from 0.63164 to 0.61914, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.7434 - loss: 0.7217 - val_accuracy: 0.7450 - val_loss: 0.6191 - learning_rate: 1.0000e-04
# Epoch 52/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.7284 - loss: 0.7445
# Epoch 52: val_loss improved from 0.61914 to 0.61688, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 320ms/step - accuracy: 0.7283 - loss: 0.7461 - val_accuracy: 0.7350 - val_loss: 0.6169 - learning_rate: 1.0000e-04
# Epoch 53/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.7234 - loss: 0.7867
# Epoch 53: val_loss improved from 0.61688 to 0.61114, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 225ms/step - accuracy: 0.7235 - loss: 0.7848 - val_accuracy: 0.7600 - val_loss: 0.6111 - learning_rate: 1.0000e-04
# Epoch 54/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7329 - loss: 0.7313
# Epoch 54: val_loss did not improve from 0.61114
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.7328 - loss: 0.7312 - val_accuracy: 0.7400 - val_loss: 0.6230 - learning_rate: 1.0000e-04
# Epoch 55/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.7587 - loss: 0.7237
# Epoch 55: val_loss did not improve from 0.61114
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.7589 - loss: 0.7232 - val_accuracy: 0.7500 - val_loss: 0.6197 - learning_rate: 1.0000e-04
# Epoch 56/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7573 - loss: 0.6836
# Epoch 56: val_loss improved from 0.61114 to 0.60985, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.7569 - loss: 0.6847 - val_accuracy: 0.7550 - val_loss: 0.6098 - learning_rate: 1.0000e-04
# Epoch 57/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.7593 - loss: 0.6983
# Epoch 57: val_loss improved from 0.60985 to 0.59854, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.7575 - loss: 0.6999 - val_accuracy: 0.7600 - val_loss: 0.5985 - learning_rate: 1.0000e-04
# Epoch 58/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.7508 - loss: 0.6708
# Epoch 58: val_loss improved from 0.59854 to 0.59159, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 221ms/step - accuracy: 0.7498 - loss: 0.6719 - val_accuracy: 0.7850 - val_loss: 0.5916 - learning_rate: 1.0000e-04
# Epoch 59/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.7301 - loss: 0.7354
# Epoch 59: val_loss did not improve from 0.59159
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.7312 - loss: 0.7341 - val_accuracy: 0.7900 - val_loss: 0.5990 - learning_rate: 1.0000e-04
# Epoch 60/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.7562 - loss: 0.6935
# Epoch 60: val_loss did not improve from 0.59159
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 211ms/step - accuracy: 0.7563 - loss: 0.6940 - val_accuracy: 0.7750 - val_loss: 0.6086 - learning_rate: 1.0000e-04
# Epoch 61/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7718 - loss: 0.6509
# Epoch 61: val_loss did not improve from 0.59159
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.7708 - loss: 0.6520 - val_accuracy: 0.7850 - val_loss: 0.6060 - learning_rate: 1.0000e-04
# Epoch 62/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7432 - loss: 0.6885
# Epoch 62: val_loss improved from 0.59159 to 0.58948, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.7440 - loss: 0.6873 - val_accuracy: 0.7850 - val_loss: 0.5895 - learning_rate: 1.0000e-04
# Epoch 63/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.7830 - loss: 0.6617
# Epoch 63: val_loss did not improve from 0.58948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 219ms/step - accuracy: 0.7828 - loss: 0.6614 - val_accuracy: 0.7750 - val_loss: 0.5898 - learning_rate: 1.0000e-04
# Epoch 64/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.7601 - loss: 0.6520
# Epoch 64: val_loss improved from 0.58948 to 0.57978, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - accuracy: 0.7605 - loss: 0.6519 - val_accuracy: 0.7700 - val_loss: 0.5798 - learning_rate: 1.0000e-04
# Epoch 65/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.7681 - loss: 0.6589
# Epoch 65: val_loss improved from 0.57978 to 0.57581, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - accuracy: 0.7700 - loss: 0.6571 - val_accuracy: 0.7700 - val_loss: 0.5758 - learning_rate: 1.0000e-04
# Epoch 66/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.7943 - loss: 0.6234
# Epoch 66: val_loss improved from 0.57581 to 0.55382, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - accuracy: 0.7933 - loss: 0.6243 - val_accuracy: 0.8100 - val_loss: 0.5538 - learning_rate: 1.0000e-04
# Epoch 67/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.8166 - loss: 0.6045
# Epoch 67: val_loss did not improve from 0.55382
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 312ms/step - accuracy: 0.8167 - loss: 0.6043 - val_accuracy: 0.8000 - val_loss: 0.5615 - learning_rate: 1.0000e-04
# Epoch 68/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.7782 - loss: 0.6122
# Epoch 68: val_loss did not improve from 0.55382
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.7797 - loss: 0.6111 - val_accuracy: 0.7850 - val_loss: 0.5698 - learning_rate: 1.0000e-04
# Epoch 69/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8128 - loss: 0.5839
# Epoch 69: val_loss did not improve from 0.55382
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.8115 - loss: 0.5844 - val_accuracy: 0.7900 - val_loss: 0.5646 - learning_rate: 1.0000e-04
# Epoch 70/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8105 - loss: 0.5904
# Epoch 70: val_loss improved from 0.55382 to 0.55114, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.8100 - loss: 0.5904 - val_accuracy: 0.8050 - val_loss: 0.5511 - learning_rate: 1.0000e-04
# Epoch 71/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8044 - loss: 0.5809
# Epoch 71: val_loss improved from 0.55114 to 0.53992, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - accuracy: 0.8043 - loss: 0.5814 - val_accuracy: 0.8050 - val_loss: 0.5399 - learning_rate: 1.0000e-04
# Epoch 72/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8047 - loss: 0.6144
# Epoch 72: val_loss improved from 0.53992 to 0.53314, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 220ms/step - accuracy: 0.8049 - loss: 0.6121 - val_accuracy: 0.8050 - val_loss: 0.5331 - learning_rate: 1.0000e-04
# Epoch 73/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8004 - loss: 0.5858
# Epoch 73: val_loss improved from 0.53314 to 0.53258, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 224ms/step - accuracy: 0.8011 - loss: 0.5848 - val_accuracy: 0.8150 - val_loss: 0.5326 - learning_rate: 1.0000e-04
# Epoch 74/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.8505 - loss: 0.5213
# Epoch 74: val_loss did not improve from 0.53258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 310ms/step - accuracy: 0.8499 - loss: 0.5220 - val_accuracy: 0.8100 - val_loss: 0.5497 - learning_rate: 1.0000e-04
# Epoch 75/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8134 - loss: 0.5778
# Epoch 75: val_loss did not improve from 0.53258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 203ms/step - accuracy: 0.8140 - loss: 0.5765 - val_accuracy: 0.8150 - val_loss: 0.5483 - learning_rate: 1.0000e-04
# Epoch 76/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8233 - loss: 0.5561
# Epoch 76: val_loss improved from 0.53258 to 0.52925, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.8244 - loss: 0.5553 - val_accuracy: 0.8050 - val_loss: 0.5292 - learning_rate: 1.0000e-04
# Epoch 77/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.8272 - loss: 0.5594
# Epoch 77: val_loss did not improve from 0.52925
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 281ms/step - accuracy: 0.8276 - loss: 0.5588 - val_accuracy: 0.8050 - val_loss: 0.5416 - learning_rate: 1.0000e-04
# Epoch 78/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8320 - loss: 0.5061
# Epoch 78: val_loss improved from 0.52925 to 0.52475, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 222ms/step - accuracy: 0.8320 - loss: 0.5071 - val_accuracy: 0.8100 - val_loss: 0.5247 - learning_rate: 1.0000e-04
# Epoch 79/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8382 - loss: 0.5152
# Epoch 79: val_loss improved from 0.52475 to 0.50831, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - accuracy: 0.8384 - loss: 0.5152 - val_accuracy: 0.8250 - val_loss: 0.5083 - learning_rate: 1.0000e-04
# Epoch 80/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.8523 - loss: 0.5051
# Epoch 80: val_loss did not improve from 0.50831
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 307ms/step - accuracy: 0.8520 - loss: 0.5058 - val_accuracy: 0.8350 - val_loss: 0.5091 - learning_rate: 1.0000e-04
# Epoch 81/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8262 - loss: 0.5309
# Epoch 81: val_loss improved from 0.50831 to 0.50150, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - accuracy: 0.8276 - loss: 0.5295 - val_accuracy: 0.8400 - val_loss: 0.5015 - learning_rate: 1.0000e-04
# Epoch 82/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8796 - loss: 0.4800
# Epoch 82: val_loss did not improve from 0.50150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.8789 - loss: 0.4803 - val_accuracy: 0.8100 - val_loss: 0.5208 - learning_rate: 1.0000e-04
# Epoch 83/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.8519 - loss: 0.5129
# Epoch 83: val_loss did not improve from 0.50150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 291ms/step - accuracy: 0.8512 - loss: 0.5125 - val_accuracy: 0.8200 - val_loss: 0.5226 - learning_rate: 1.0000e-04
# Epoch 84/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8439 - loss: 0.4929
# Epoch 84: val_loss did not improve from 0.50150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 223ms/step - accuracy: 0.8445 - loss: 0.4927 - val_accuracy: 0.8350 - val_loss: 0.5078 - learning_rate: 1.0000e-04
# Epoch 85/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8566 - loss: 0.4712
# Epoch 85: val_loss did not improve from 0.50150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.8579 - loss: 0.4712 - val_accuracy: 0.8400 - val_loss: 0.5025 - learning_rate: 1.0000e-04
# Epoch 86/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8491 - loss: 0.4868
# Epoch 86: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 86: val_loss did not improve from 0.50150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.8487 - loss: 0.4879 - val_accuracy: 0.8250 - val_loss: 0.5101 - learning_rate: 1.0000e-04
# Epoch 87/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.8540 - loss: 0.4917
# Epoch 87: val_loss did not improve from 0.50150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 299ms/step - accuracy: 0.8548 - loss: 0.4907 - val_accuracy: 0.8400 - val_loss: 0.5082 - learning_rate: 2.0000e-05
# Epoch 88/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8510 - loss: 0.4942
# Epoch 88: val_loss did not improve from 0.50150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 201ms/step - accuracy: 0.8524 - loss: 0.4927 - val_accuracy: 0.8400 - val_loss: 0.5058 - learning_rate: 2.0000e-05
# Epoch 89/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8699 - loss: 0.4555
# Epoch 89: val_loss improved from 0.50150 to 0.50107, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - accuracy: 0.8699 - loss: 0.4556 - val_accuracy: 0.8400 - val_loss: 0.5011 - learning_rate: 2.0000e-05
# Epoch 90/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8783 - loss: 0.4444
# Epoch 90: val_loss improved from 0.50107 to 0.49418, saving model to best_intent_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ...
# Epoch 17/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.5057 - loss: 1.3148
# Epoch 17: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.5066 - loss: 1.3126 - val_accuracy: 0.5150 - val_loss: 1.3888 - learning_rate: 1.0000e-04
# Epoch 18/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.5573 - loss: 1.2605
# Epoch 18: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 389ms/step - accuracy: 0.5563 - loss: 1.2609 - val_accuracy: 0.5300 - val_loss: 1.3497 - learning_rate: 1.0000e-04
# Epoch 19/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.5351 - loss: 1.2919
# Epoch 19: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.5365 - loss: 1.2883 - val_accuracy: 0.5750 - val_loss: 1.2945 - learning_rate: 1.0000e-04
# Epoch 20/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.5855 - loss: 1.1739
# Epoch 20: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.5842 - loss: 1.1762 - val_accuracy: 0.5650 - val_loss: 1.2613 - learning_rate: 1.0000e-04
# Epoch 21/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.5410 - loss: 1.2033
# Epoch 21: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 459ms/step - accuracy: 0.5404 - loss: 1.2039 - val_accuracy: 0.5600 - val_loss: 1.2284 - learning_rate: 1.0000e-04
# Epoch 22/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.5797 - loss: 1.2007
# Epoch 22: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 215ms/step - accuracy: 0.5813 - loss: 1.1975 - val_accuracy: 0.5850 - val_loss: 1.1954 - learning_rate: 1.0000e-04
# Epoch 23/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.5896 - loss: 1.1697
# Epoch 23: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - accuracy: 0.5905 - loss: 1.1667 - val_accuracy: 0.5600 - val_loss: 1.1663 - learning_rate: 1.0000e-04
# Epoch 24/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.5835 - loss: 1.1434
# Epoch 24: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.5833 - loss: 1.1419 - val_accuracy: 0.5850 - val_loss: 1.1429 - learning_rate: 1.0000e-04
# Epoch 25/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.5692 - loss: 1.1708
# Epoch 25: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - accuracy: 0.5692 - loss: 1.1690 - val_accuracy: 0.5750 - val_loss: 1.1136 - learning_rate: 1.0000e-04
# Epoch 26/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.6148 - loss: 1.0706
# Epoch 26: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 297ms/step - accuracy: 0.6161 - loss: 1.0693 - val_accuracy: 0.5900 - val_loss: 1.0701 - learning_rate: 1.0000e-04
# Epoch 27/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6091 - loss: 1.0614
# Epoch 27: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 211ms/step - accuracy: 0.6093 - loss: 1.0612 - val_accuracy: 0.6000 - val_loss: 1.0388 - learning_rate: 1.0000e-04
# Epoch 28/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.6386 - loss: 0.9861
# Epoch 28: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.6383 - loss: 0.9881 - val_accuracy: 0.6050 - val_loss: 1.0146 - learning_rate: 1.0000e-04
# Epoch 29/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.6167 - loss: 1.0473
# Epoch 29: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 334ms/step - accuracy: 0.6174 - loss: 1.0474 - val_accuracy: 0.6350 - val_loss: 0.9887 - learning_rate: 1.0000e-04
# Epoch 30/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.6116 - loss: 1.0094
# Epoch 30: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - accuracy: 0.6120 - loss: 1.0096 - val_accuracy: 0.6500 - val_loss: 0.9458 - learning_rate: 1.0000e-04
# Epoch 31/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6541 - loss: 0.9537
# Epoch 31: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.6539 - loss: 0.9545 - val_accuracy: 0.6600 - val_loss: 0.9280 - learning_rate: 1.0000e-04
# Epoch 32/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.6506 - loss: 0.9731
# Epoch 32: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 333ms/step - accuracy: 0.6496 - loss: 0.9742 - val_accuracy: 0.6500 - val_loss: 0.9034 - learning_rate: 1.0000e-04
# Epoch 33/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.6790 - loss: 0.8911
# Epoch 33: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.6786 - loss: 0.8925 - val_accuracy: 0.6600 - val_loss: 0.8776 - learning_rate: 1.0000e-04
# Epoch 34/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.6774 - loss: 0.9179
# Epoch 34: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 0.6767 - loss: 0.9207 - val_accuracy: 0.6950 - val_loss: 0.8579 - learning_rate: 1.0000e-04
# Epoch 35/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.6773 - loss: 0.8769
# Epoch 35: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 291ms/step - accuracy: 0.6770 - loss: 0.8769 - val_accuracy: 0.6900 - val_loss: 0.8320 - learning_rate: 1.0000e-04
# Epoch 36/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6728 - loss: 0.9164
# Epoch 36: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.6723 - loss: 0.9195 - val_accuracy: 0.7050 - val_loss: 0.8001 - learning_rate: 1.0000e-04
# Epoch 37/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.6851 - loss: 0.8815
# Epoch 37: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - accuracy: 0.6853 - loss: 0.8823 - val_accuracy: 0.6950 - val_loss: 0.7931 - learning_rate: 1.0000e-04
# Epoch 38/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.6897 - loss: 0.8686
# Epoch 38: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.6896 - loss: 0.8700 - val_accuracy: 0.6950 - val_loss: 0.7848 - learning_rate: 1.0000e-04
# Epoch 39/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.7213 - loss: 0.8374
# Epoch 39: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.7210 - loss: 0.8364 - val_accuracy: 0.7000 - val_loss: 0.7851 - learning_rate: 1.0000e-04
# Epoch 40/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.6909 - loss: 0.8537
# Epoch 40: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.6911 - loss: 0.8533 - val_accuracy: 0.7100 - val_loss: 0.7708 - learning_rate: 1.0000e-04
# Epoch 41/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7157 - loss: 0.8578
# Epoch 41: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.7160 - loss: 0.8567 - val_accuracy: 0.7050 - val_loss: 0.7627 - learning_rate: 1.0000e-04
# Epoch 42/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.7305 - loss: 0.7624
# Epoch 42: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.7300 - loss: 0.7646 - val_accuracy: 0.6950 - val_loss: 0.7655 - learning_rate: 1.0000e-04
# Epoch 43/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.7372 - loss: 0.8154
# Epoch 43: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 261ms/step - accuracy: 0.7358 - loss: 0.8159 - val_accuracy: 0.6750 - val_loss: 0.7576 - learning_rate: 1.0000e-04
# Epoch 44/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.7149 - loss: 0.8307
# Epoch 44: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 295ms/step - accuracy: 0.7154 - loss: 0.8295 - val_accuracy: 0.6850 - val_loss: 0.7528 - learning_rate: 1.0000e-04
# Epoch 45/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.7247 - loss: 0.8066
# Epoch 45: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - accuracy: 0.7247 - loss: 0.8048 - val_accuracy: 0.6800 - val_loss: 0.7468 - learning_rate: 1.0000e-04
# Epoch 46/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7224 - loss: 0.7900
# Epoch 46: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - accuracy: 0.7224 - loss: 0.7906 - val_accuracy: 0.7000 - val_loss: 0.7349 - learning_rate: 1.0000e-04
# Epoch 47/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7623 - loss: 0.7232
# Epoch 47: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.7629 - loss: 0.7226 - val_accuracy: 0.7100 - val_loss: 0.7226 - learning_rate: 1.0000e-04
# Epoch 48/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7369 - loss: 0.8042
# Epoch 48: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.7368 - loss: 0.8048 - val_accuracy: 0.7150 - val_loss: 0.7265 - learning_rate: 1.0000e-04
# Epoch 49/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.7769 - loss: 0.6881
# Epoch 49: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 307ms/step - accuracy: 0.7775 - loss: 0.6880 - val_accuracy: 0.7200 - val_loss: 0.7114 - learning_rate: 1.0000e-04
# Epoch 50/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7536 - loss: 0.7470
# Epoch 50: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - accuracy: 0.7541 - loss: 0.7472 - val_accuracy: 0.7350 - val_loss: 0.6888 - learning_rate: 1.0000e-04
# Epoch 51/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7987 - loss: 0.6912
# Epoch 51: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.7981 - loss: 0.6927 - val_accuracy: 0.7400 - val_loss: 0.6777 - learning_rate: 1.0000e-04
# Epoch 52/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.7748 - loss: 0.7015
# Epoch 52: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 363ms/step - accuracy: 0.7742 - loss: 0.7023 - val_accuracy: 0.7500 - val_loss: 0.6875 - learning_rate: 1.0000e-04
# Epoch 53/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8074 - loss: 0.6460
# Epoch 53: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.8061 - loss: 0.6492 - val_accuracy: 0.7450 - val_loss: 0.6889 - learning_rate: 1.0000e-04
# Epoch 54/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7890 - loss: 0.6675
# Epoch 54: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.7883 - loss: 0.6698 - val_accuracy: 0.7650 - val_loss: 0.6563 - learning_rate: 1.0000e-04
# Epoch 55/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.7628 - loss: 0.7264
# Epoch 55: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - accuracy: 0.7627 - loss: 0.7250 - val_accuracy: 0.7600 - val_loss: 0.6382 - learning_rate: 1.0000e-04
# Epoch 56/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.7798 - loss: 0.6592
# Epoch 56: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.7797 - loss: 0.6613 - val_accuracy: 0.7800 - val_loss: 0.6185 - learning_rate: 1.0000e-04
# Epoch 57/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8093 - loss: 0.6508
# Epoch 57: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.8087 - loss: 0.6500 - val_accuracy: 0.7900 - val_loss: 0.6249 - learning_rate: 1.0000e-04
# Epoch 58/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8014 - loss: 0.6367
# Epoch 58: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 223ms/step - accuracy: 0.8013 - loss: 0.6371 - val_accuracy: 0.7850 - val_loss: 0.6251 - learning_rate: 1.0000e-04
# Epoch 59/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8320 - loss: 0.5874
# Epoch 59: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - accuracy: 0.8317 - loss: 0.5888 - val_accuracy: 0.7850 - val_loss: 0.6155 - learning_rate: 1.0000e-04
# Epoch 60/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8002 - loss: 0.6146
# Epoch 60: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.8002 - loss: 0.6146 - val_accuracy: 0.7950 - val_loss: 0.6084 - learning_rate: 1.0000e-04
# Epoch 61/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8035 - loss: 0.6138
# Epoch 61: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.8033 - loss: 0.6157 - val_accuracy: 0.7850 - val_loss: 0.5963 - learning_rate: 1.0000e-04
# Epoch 62/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8023 - loss: 0.6194
# Epoch 62: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.8024 - loss: 0.6196 - val_accuracy: 0.7850 - val_loss: 0.6070 - learning_rate: 1.0000e-04
# Epoch 63/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.8428 - loss: 0.5467
# Epoch 63: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 326ms/step - accuracy: 0.8424 - loss: 0.5477 - val_accuracy: 0.7850 - val_loss: 0.6032 - learning_rate: 1.0000e-04
# Epoch 64/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8290 - loss: 0.5847
# Epoch 64: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 241ms/step - accuracy: 0.8286 - loss: 0.5847 - val_accuracy: 0.7850 - val_loss: 0.6364 - learning_rate: 1.0000e-04
# Epoch 65/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8118 - loss: 0.5870
# Epoch 65: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.8129 - loss: 0.5864 - val_accuracy: 0.7600 - val_loss: 0.6231 - learning_rate: 1.0000e-04
# Epoch 66/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.8335 - loss: 0.5699
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 66: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 395ms/step - accuracy: 0.8334 - loss: 0.5703 - val_accuracy: 0.7550 - val_loss: 0.6243 - learning_rate: 1.0000e-04
# Epoch 67/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.8086 - loss: 0.6011
# Epoch 67: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - accuracy: 0.8083 - loss: 0.6015 - val_accuracy: 0.7550 - val_loss: 0.6136 - learning_rate: 2.0000e-05
# Epoch 68/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8230 - loss: 0.5788
# Epoch 68: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.8235 - loss: 0.5789 - val_accuracy: 0.7700 - val_loss: 0.6033 - learning_rate: 2.0000e-05
# Epoch 69/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8278 - loss: 0.5617
# Epoch 69: val_loss did not improve from 0.48716
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 304ms/step - accuracy: 0.8281 - loss: 0.5621 - val_accuracy: 0.7700 - val_loss: 0.5991 - learning_rate: 2.0000e-05
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7864 - loss: 0.5713
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.65      0.67       200
#            1       0.80      0.93      0.86       200
#            2       0.91      0.96      0.94       200
#            3       0.66      0.71      0.68       200
#            4       0.90      0.70      0.79       200
#
#     accuracy                           0.79      1000
#    macro avg       0.79      0.79      0.79      1000
# weighted avg       0.79      0.79      0.79      1000
#
#
# Average validation accuracy: 0.7910 ± 0.0325
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
#
# Test Query: How do I properly dispose of electronic waste?
# Predicted Intent: Public Awareness Tips
# Confidence: 0.68
